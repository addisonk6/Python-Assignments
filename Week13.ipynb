# %% [markdown]
# <a href="https://colab.research.google.com/github/addisonk6/Python-Assignments/blob/main/Week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py

# IMPORTS

# none needed


# FUNCTIONS

# write_entry
# take filename + entry
# open file in 'a'
# write entry + \n

# read_journal
# take filename
# open file in 'r'
# print contents


# PROGRAM LOGIC

# set filename
# loop:
#   ask W / R / Q
#   if W = get input, save
#   if R = read file
#   if Q = quit
#   else = error message
