# %% [markdown]
# <a href="https://colab.research.google.com/github/addisonk6/Python-Assignments/blob/main/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATMENTS
#(None)


#FUNCTION DEFINITIONS
#Function: calculate_bill

#Parameters:
  #car_ID
  #days_rented
  #start_odometer
  #end_odometer

def calculate_bill(car_ID, days_rented, start_odometer, end_odometer, charged_miles):

# 1. Get daily rate based on the car ID.
  #If ID  is B = Budget rate
  #If ID  is S = Standard rate
  #If ID  is L = Luxury rate
  if car_ID == "B":
      daily_rate = 40
      class_name = "Budget"

  elif car_ID == "S":
      daily_rate = 40
      class_name = "Standard"

  else:
    daily_rate: 100
    class_name = "Luxury"
# 2. Calculate miles_driven
  #end_odometer - start_odometer

  miles_driven = end_odometer - start_odometer

# 3. Determine miles charged
  #if miles > 100, then charge 0.35 for each mile over

  if miles_driven > 100:
    charged_miles = miles_driven - 100
  else:
    charged_miles = 0



# 4. Get daily rental cost



# 5. Calculate total bill




#PROGRAM LOGIC

# 1. Ask the user for the car classification code (B, S, L)
  # If the code is not B, S, or L, display an error message, ask the user again until valid input is given

  while True:
    car_ID = input("Enter car class (B = Budget, S = Standard, L = Luxury): ").upper()

    if car_ID in ["B", "S", "L"]:
        break
    else:
        print("Invalid code. Please enter B, S, or L")
# 2. Number of days rented

days_rented = int(input("Enter number of rental days: "))

# 3. Ask for the user start and end odometer reading

start_odometer = int(input("Enter starting odometer reading: "))
end_odometer = int(input("Enter ending odometer reading: "))

# 4. Call calculate_bill function
  #car_ID
  #days_rented
  #start_odometer
  #end_odometer

# 5. Diplay results (Car class name, total miles driven, charged miles, and total bill)
calculate_bill(car_ID, days_rented, start_odometer, end_odometer, charged_miles)
