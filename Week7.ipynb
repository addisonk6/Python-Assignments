# %% [markdown]
# <a href="https://colab.research.google.com/github/addisonk6/Python-Assignments/blob/main/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### Import Statments ####

#### Function Definitions ####

# Define a function: evaluate_guess, (gets users guess and compares it to the random number) gives feedback
# Define random number and guess from user
# If not guessed correctly the send back message to tell them that it is incorrect and try again
  # Check if users guess equals random number
    # If so, tell the user they won
    # Return true
  # Elif the user guess is less than the random number
    # If so, tell user the number is too low
    # return False
  # Elif the user guess is higher than the random number
    # If so, tell user the number is to high
    # Return False
  # Allow guessses until guessed correctly

#### Program Logic ####

# Generate a random number
# Initialize a default user guess (for when the haven't made an attempt)

# while the user guess is wrong (call evaluate_guess function)
  # ask for a guess
