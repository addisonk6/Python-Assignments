# %% [markdown]
# <a href="https://colab.research.google.com/github/addisonk6/Python-Assignments/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
name = "Taylor June"
goal = "My goal is to become a doctor."
birth_year = 1995
current_year = 2026
# Calculate Age
age = current_year - birth_year
# Print top border
print("=" * 25)
# Print bio sentence
print("My name is " + name + " and I am " + str(age) + " years old. " + goal)
# Print bottom border
print ("=" * 25)
# Out:
# ...
# My name is Taylor June and I am 31 years old. My goal is to become a doctor.
# ...
