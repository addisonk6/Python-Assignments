# %% [markdown]
# <a href="https://colab.research.google.com/github/addisonk6/Python-Assignments/blob/main/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py
# IMPORT STATEMENTS


# FUNCTION DEFINITIONS

# Function: add_students(gradebook)
# - This function will take in a dictionary
# - Use a loop to keep asking for student names
# - If user types "done", stop the loop
# - Ask for a grade (0–100) for each student
# - Store student name as key and grade as value in dictionary

# Function: calculate_average(gradebook)
# - This function will take in the dictionary
# - Get all grades using .values()
# - Add all grades together
# - Divide by number of students
# - Return the average
# - If no students, return 0 to avoid error


# PROGRAM LOGIC

# - Create empty dictionary called gradebook
# - Call add_students to fill the dictionary
# - Call calculate_average to get class average
# - Print each student and their grade
# - Print the class average formatted to 2 decimal places
